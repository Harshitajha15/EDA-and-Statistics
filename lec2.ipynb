# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\lenovo\Desktop\Data Science_Aug-Oct\EDA\cleaned_googleplaystore_data.csv")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3],[4,5,6])
plt.show()

# %%
pip show matplotlib
# Out:
# Name: matplotlib
# Version: 3.9.2
# Summary: Python plotting package
# Home-page: https://matplotlib.org
# Author: John D. Hunter, Michael Droettboom
# Author-email: Unknown <matplotlib-users@python.org>
# License: License agreement for matplotlib versions 1.3.0 and later
# ...
#
#         1. This LICENSE AGREEMENT is between the Matplotlib Development Team
#         ("MDT"), and the Individual or Organization ("Licensee") accessing and
#         otherwise using matplotlib software in source or binary form and its
#         associated documentation.
#
#         2. Subject to the terms and conditions of this License Agreement, MDT
#         hereby grants Licensee a nonexclusive, royalty-free, world-wide license
#         to reproduce, analyze, test, perform and/or display publicly, prepare
#         derivative works, distribute, and otherwise use matplotlib
#         alone or in any derivative version, provided, however, that MDT's
# ...

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    NaN       Everyone
# 1      967  14000.0    500000  Free    NaN       Everyone
# 2    87510   8700.0   5000000  Free    NaN       Everyone
# 3   215644  25000.0  50000000  Free    NaN           Teen
# 4      967   2800.0    100000  Free    NaN       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %%
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10048        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10766                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated('App')]
# Out:
#                                       App       Category  Rating  Reviews  \
# 229          Quick PDF Scanner + OCR FREE       BUSINESS     4.2    80805
# 236                                   Box       BUSINESS     4.2   159872
# 239                    Google My Business       BUSINESS     4.4    70991
# 256                   ZOOM Cloud Meetings       BUSINESS     4.4    31614
# 261             join.me - Simple Meetings       BUSINESS     4.0     6989
# ...                                   ...            ...     ...      ...
# 10713                  FarmersOnly Dating         DATING     3.0     1145
# 10718  Firefox Focus: The privacy browser  COMMUNICATION     4.4    36981
# 10728                         FP Notebook        MEDICAL     4.5      410
# 10751      Slickdeals: Coupons & Shopping       SHOPPING     4.5    33599
# 10766                                AAFP        MEDICAL     3.8       63
#
#           Size  Installs  Type  Price Content Rating         Genres  \
# ...

# %%
df.drop_duplicates(subset=['App'],keep="first")
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite â€“ FREE Live Cool Themes, Hid...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                   Sya9a Maroc - FR               FAMILY
# 10835                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10836                             Parkinson Exercices FR              MEDICAL
# 10837                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10838      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10839 entries, 0 to 10838
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10838 non-null  object
#  1   Category        10839 non-null  object
#  2   Rating          9366 non-null   float64
#  3   Reviews         10839 non-null  int64
#  4   Size            9145 non-null   float64
#  5   Installs        10839 non-null  int64
#  6   Type            10839 non-null  object
#  7   Price           800 non-null    float64
#  8   Content Rating  10839 non-null  object
#  9   Genres          10839 non-null  object
#  10  Last Updated    10839 non-null  object
#  11  Current Ver     10831 non-null  object
#  12  Android Ver     9476 non-null   object
#  13  day             10839 non-null  int64
#  14  month           10839 non-null  int64
#  15  year            10839 non-null  int64
# dtypes: float64(3), int64(5), object(8)
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver', 'day', 'month', 'year'],
#       dtype='object')

# %%
neumerical_feature=[feature for feature in df.columns if df[feature].dtype !="O"]

# %%
neumerical_feature
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
categorical_feature=[feature for feature in df.columns if df[feature].dtype =="O"]

# %%
categorical_feature
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Last Updated',
#  'Current Ver',
#  'Android Ver']

# %%
df['Type'].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.619245
# Paid     7.380755
# Name: proportion, dtype: float64

# %%
for col in categorical_feature:
    print(f"{col}):{df[col].value_counts(normalize=True)*100}")
    print("--------------------------------------")
# Out:
# App):App
# ROBLOX                                               0.083041
# CBS Sports App - Scores, News, Stats & Watch Live    0.073814
# Candy Crush Saga                                     0.064588
# Duolingo: Learn Languages Free                       0.064588
# 8 Ball Pool                                          0.064588
#                                                        ...
# Photo Designer - Write your name with shapes         0.009227
# payermonstationnement.fr                             0.009227
# News Minecraft.fr                                    0.009227
# Bulgarian French Dictionary Fr                       0.009227
# Manga-FR - Anime Vostfr                              0.009227
# Name: proportion, Length: 9657, dtype: float64
# --------------------------------------
# Category):Category
# FAMILY                 18.184334
# GAME                   10.554479
# TOOLS                   7.777470
# MEDICAL                 4.271612
# BUSINESS                4.243934
# ...

# %%
sns.countplot(x="Type", data=df)
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
sns.kdeplot(df["Reviews"])
# Out:
# <Axes: xlabel='Reviews', ylabel='Density'>

# %%
sns.kdeplot(df["Rating"])
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize=(15,15))
plt.suptitle("Univariate Analysis of Numerical Features", fontsize='20',fontweight="bold")

for i in range(0,len(neumerical_feature)):
    plt.subplot(5, 3 , i+1)
    sns.kdeplot(x=neumerical_feature[i] , data=df , shade=True , color='g')
    # plt.xlable(neumerical_feature[i])
    plt.tight_layout()

# %%
plt.hist(df["Reviews"],kde=True)
# Out:
# (array([1.0713e+04, 8.1000e+01, 1.9000e+01, 9.0000e+00, 0.0000e+00,
#         5.0000e+00, 0.0000e+00, 3.0000e+00, 7.0000e+00, 2.0000e+00]),
#  array([       0.        ,  7815830.6       , 15631661.2       ,
#         23447491.8       , 31263322.4       , 39079153.        ,
#         46894983.59999999, 54710814.2       , 62526644.8       ,
#         70342475.39999999, 78158306.        ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df["Rating"])
# Out:
# (array([  17.,   18.,   41.,   74.,  137.,  446.,  879., 1662., 4175.,
#         1917.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    NaN       Everyone
# 1      967  14000.0    500000  Free    NaN       Everyone
# 2    87510   8700.0   5000000  Free    NaN       Everyone
# 3   215644  25000.0  50000000  Free    NaN           Teen
# 4      967   2800.0    100000  Free    NaN       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %% [markdown]
# Univariate Analysis
#
# most popular category in app

# %%
df["Category"].value_counts().plot.pie(y=df["Category"], figsize=(15,15),autopct ='%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
#top 10 category
df["Category"].value_counts()[:10]
# Out:
# Category
# FAMILY             1971
# GAME               1144
# TOOLS               843
# MEDICAL             463
# BUSINESS            460
# PRODUCTIVITY        424
# PERSONALIZATION     392
# COMMUNICATION       387
# SPORTS              384
# LIFESTYLE           382
# Name: count, dtype: int64

# %%
#which category having largest number of installation
df_cat_installs=df.groupby(['Category'])['Installs'].sum().sort_values(ascending=False).reset_index()

# %%
df_cat_installs
# Out:
#                Category     Installs
# 0                  GAME  35086024415
# 1         COMMUNICATION  32647276251
# 2          PRODUCTIVITY  14176091369
# 3                SOCIAL  14069867902
# 4                 TOOLS  11452771915
# 5                FAMILY  10258263505
# 6           PHOTOGRAPHY  10088247655
# 7    NEWS_AND_MAGAZINES   7496317760
# 8      TRAVEL_AND_LOCAL   6868887146
# 9         VIDEO_PLAYERS   6222002720
# 10             SHOPPING   3247848785
# 11        ENTERTAINMENT   2869160000
# 12      PERSONALIZATION   2325494782
# 13  BOOKS_AND_REFERENCE   1921469576
# 14               SPORTS   1751174498
# 15   HEALTH_AND_FITNESS   1583072512
# 16             BUSINESS   1001914865
# 17              FINANCE    876648734
# 18            EDUCATION    871452000
# 19  MAPS_AND_NAVIGATION    724281890
# 20            LIFESTYLE    537643539
# 21              WEATHER    426100520
# 22       FOOD_AND_DRINK    273898751
# 23               DATING    264310807
# ...

# %%
df_2=df_cat_installs.head(10)

# %%
sns.barplot(x="Installs" , y="Category" , data=df_2)
# Out:
# <Axes: xlabel='Installs', ylabel='Category'>

# %% [markdown]
# What are the Top5 most installed APPs in Each popular Categories?

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite â€“ FREE Live Cool Themes, Hid...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#    Reviews     Size  Installs  Type  Price Content Rating  \
# 0      159  19000.0     10000  Free    NaN       Everyone
# 1      967  14000.0    500000  Free    NaN       Everyone
# 2    87510   8700.0   5000000  Free    NaN       Everyone
# 3   215644  25000.0  50000000  Free    NaN           Teen
# 4      967   2800.0    100000  Free    NaN       Everyone
#
#                       Genres Last Updated         Current Ver Android Ver  \
# 0               Art & Design   2018-01-07               1.0.0      4.0.3
# ...

# %% [markdown]
# this is going to be multivariate analysis : installs , app, category .

# %%
df.groupby(['Category', 'App'])['Installs']
